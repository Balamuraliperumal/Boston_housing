# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df=df.rename(columns={'MEDV':'Price'})
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# Price       0
# dtype: int64

# %%
df.CRIM.mean()
# Out:
# 3.6118739711934156

# %%
df['CRIM']=df['CRIM'].fillna(df.CRIM.mean())

# %%
df['ZN']=df['ZN'].fillna(df.ZN.mode()[0])

# %%
df['INDUS']=df.INDUS.fillna(df.INDUS.mean())

# %%
df['CHAS']=df.CHAS.fillna(df.CHAS.mode()[0])

# %%
df['AGE']=df.AGE.fillna(df.AGE.mean())

# %%
df['LSTAT']=df.LSTAT.fillna(df['LSTAT'].mean())

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT  Price
# 0  396.90   4.980000   24.0
# 1  396.90   9.140000   21.6
# 2  392.83   4.030000   34.7
# 3  394.63   2.940000   33.4
# 4  396.90  12.715432   36.2

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.182113  0.391161 -0.053710  0.410377 -0.215434  0.344934
# ZN      -0.182113  1.000000 -0.507800 -0.032992 -0.498619  0.312295 -0.534831
# INDUS    0.391161 -0.507800  1.000000  0.054172  0.740965 -0.381457  0.614592
# CHAS    -0.053710 -0.032992  0.054172  1.000000  0.070867  0.106797  0.073549
# NOX      0.410377 -0.498619  0.740965  0.070867  1.000000 -0.302188  0.711461
# RM      -0.215434  0.312295 -0.381457  0.106797 -0.302188  1.000000 -0.241351
# AGE      0.344934 -0.534831  0.614592  0.073549  0.711461 -0.241351  1.000000
# DIS     -0.366523  0.632428 -0.699639 -0.092318 -0.769230  0.205246 -0.724353
# RAD      0.608886 -0.300061  0.593176 -0.003339  0.611441 -0.209847  0.449989
# TAX      0.566528 -0.304385  0.716062 -0.035822  0.668023 -0.292048  0.500589
# PTRATIO  0.273384 -0.394622  0.384806 -0.109451  0.188933 -0.355501  0.262723
# B       -0.370163  0.170125 -0.354597  0.050608 -0.380051  0.128069 -0.265282
# LSTAT    0.434044 -0.400912  0.567354 -0.047808  0.572379 -0.602962  0.574893
# Price   -0.379695  0.362292 -0.478657  0.183844 -0.427321  0.695360 -0.380223
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     Price
# CRIM    -0.366523  0.608886  0.566528  0.273384 -0.370163  0.434044 -0.379695
# ZN       0.632428 -0.300061 -0.304385 -0.394622  0.170125 -0.400912  0.362292
# INDUS   -0.699639  0.593176  0.716062  0.384806 -0.354597  0.567354 -0.478657
# CHAS    -0.092318 -0.003339 -0.035822 -0.109451  0.050608 -0.047808  0.183844
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.572379 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.602962  0.695360
# AGE     -0.724353  0.449989  0.500589  0.262723 -0.265282  0.574893 -0.380223
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.483429  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.468440 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.524545 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.373343 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.368886  0.333461
# LSTAT   -0.483429  0.468440  0.524545  0.373343 -0.368886  1.000000 -0.721975
# Price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.721975  1.000000

# %%
sns.pairplot(df)
# Out:
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.scatter(df['CRIM'],df['Price'])
plt.xlabel('CRIM')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(df['RM'],df['Price'])
plt.xlabel('RM')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x='RM',y='Price',data=df)
# Out:
# <Axes: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x='PTRATIO',y='Price',data=df)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='Price'>

# %%
# X,Y data for the train and test purpose

x=df.iloc[:,:-1]
y=df.iloc[:,-1:]

# %%
y
# Out:
#      Price
# 0     24.0
# 1     21.6
# 2     34.7
# 3     33.4
# 4     36.2
# ..     ...
# 501   22.4
# 502   20.6
# 503   23.9
# 504   22.0
# 505   11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158  0.0  10.01   0.0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142  0.0   6.91   0.0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393  0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570  0.0  18.10   0.0  0.580  5.926  71.0  2.9084   24  666
#
#      PTRATIO       B      LSTAT
# 5       18.7  394.12   5.210000
# 116     17.8  393.30  12.715432
# 45      17.9  396.90  10.210000
# 16      21.0  386.85   6.580000
# 468     20.2  368.74  18.130000

# %%
# Standardize the dataset
from  sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train,X_test
# Out:
# (array([[-0.42002854, -0.48778231, -1.31729854, ...,  0.18727079,
#           0.39651419, -1.04595325],
#         [-0.4076886 , -0.48778231, -0.15405495, ..., -0.21208981,
#           0.3870674 ,  0.03449941],
#         [-0.40285597, -0.48778231, -0.61459839, ..., -0.16771641,
#           0.42854113, -0.3261728 ],
#         ...,
#         [-0.42182865,  3.07160832, -1.34255415, ..., -0.56707702,
#           0.35987906, -0.9336675 ],
#         [ 0.93011786, -0.48778231,  1.04781486, ...,  0.8528718 ,
#          -2.87841346,  1.55389374],
#         [-0.39590057, -0.48778231, -0.36947043, ...,  1.16348561,
#          -3.32828832, -0.26571124]]),
#  array([[-0.41251638, -0.48778231,  0.00549984, ..., -0.74457062,
#           0.41241246, -0.49460143],
#         [-0.41680315,  1.291913  , -0.68887959, ..., -0.30083661,
#           0.42854113, -1.28779948],
#         [-0.41082301, -0.48778231,  2.47995639, ...,  0.8084984 ,
#           0.35031705,  0.80532207],
#         ...,
#         [-0.35973226, -0.48778231, -0.7200777 , ..., -0.38958342,
#           0.25688594, -1.12944778],
#         [ 0.25333977, -0.48778231,  1.04781486, ...,  0.8528718 ,
#          -2.98970133,  0.5390033 ],
#         [ 0.78024446, -0.48778231,  1.04781486, ...,  0.8528718 ,
#           0.33199949,  0.57067364]]))

# %%
# Train the model
from sklearn.linear_model import LinearRegression

regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [[-1.05375488  0.66447003 -0.08322479  0.96234701 -1.62703202  3.16746272
#   -0.71503109 -3.01542163  1.66911095 -1.15701471 -2.01716579  1.00951406
#   -3.29615471]]

# %%
print(regression.intercept_)
# Out:
# [23.01581921]

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#Model Prediction

pred=regression.predict(X_test)
pred
# Out:
# array([[28.9770563 ],
#        [37.11537411],
#        [15.21638223],
#        [25.68471837],
#        [18.52245683],
#        [22.97862249],
#        [18.0294965 ],
#        [14.40905246],
#        [22.07985409],
#        [20.83947467],
#        [25.19010803],
#        [18.51886139],
#        [-6.2511157 ],
#        [21.93726799],
#        [19.05748941],
#        [25.42295356],
#        [19.31356941],
#        [ 5.68444385],
#        [40.78054795],
#        [17.18365475],
#        [24.93723959],
#        [30.33435465],
#        [11.40131883],
#        [22.75776543],
#        [17.51792319],
#        [15.13180877],
#        [21.47086207],
#        [14.53076603],
#        [22.85206922],
#        [19.59734298],
#        [22.21031579],
#        [25.3027039 ],
#        [25.01977405],
#        [17.35223348],
#        [16.24708502],
#        [17.30969893],
#        [30.96708214],
#        [20.42967659],
#        [24.77968559],
#        [22.93387174],
#        [14.54479037],
#        [31.72210323],
#        [42.68239248],
#        [18.06197921],
#        [27.40293206],
#        [16.56237573],
#        [13.95529748],
#        [26.61662448],
#        [19.76455509],
#        [30.30957496],
#        [21.08235063],
#        [33.5029566 ],
#        [15.97623669],
#        [26.2934281 ],
#        [39.6184144 ],
#        [22.55513948],
#        [18.47190079],
#        [32.90148187],
#        [25.30676977],
#        [12.92403708],
#        [22.87008021],
#        [30.91964298],
#        [31.60720225],
#        [16.80968648],
#        [21.26515862],
#        [17.1754213 ],
#        [19.98281435],
#        [26.40386327],
#        [31.20638077],
#        [11.78037787],
#        [21.03419411],
#        [26.66268664],
#        [10.97458425],
#        [13.17708938],
#        [24.03849931],
#        [ 5.67419633],
#        [21.45758486],
#        [41.43224371],
#        [18.16469958],
#        [ 9.53513477],
#        [21.48785419],
#        [12.82951964],
#        [21.85406671],
#        [ 9.1711329 ],
#        [22.79057795],
#        [32.62976034],
#        [19.10846466],
#        [25.81264189],
#        [29.01606429],
#        [19.78115095],
#        [26.06325692],
#        [ 5.60423209],
#        [19.66795799],
#        [15.70876039],
#        [12.09332611],
#        [20.27383511],
#        [23.71690626],
#        [-0.29340212],
#        [13.62673139],
#        [15.61358927],
#        [22.68663484],
#        [24.70506025],
#        [10.44862595],
#        [19.74015364],
#        [22.97429679],
#        [12.60346387],
#        [18.51910974],
#        [26.04772854],
#        [21.26223467],
#        [24.70210772],
#        [ 7.91730141],
#        [20.25758815],
#        [22.19871962],
#        [27.50828159],
#        [32.0499578 ],
#        [14.81246939],
#        [34.77397533],
#        [13.07425246],
#        [21.38526977],
#        [28.03374052],
#        [15.4005868 ],
#        [25.24370667],
#        [ 3.45679744],
#        [23.76969515],
#        [26.35887919],
#        [23.15126572],
#        [25.37469699],
#        [33.18427839],
#        [21.80965541],
#        [38.48550151],
#        [14.35684768],
#        [26.30346613],
#        [17.61012408],
#        [20.82208466],
#        [10.50281026],
#        [20.55144603],
#        [22.70566183],
#        [31.89581433],
#        [31.78928307],
#        [15.53055226],
#        [17.03398446],
#        [29.10436833],
#        [25.01208194],
#        [17.60788106],
#        [ 6.57228174],
#        [25.89381559],
#        [23.90459999],
#        [20.49218438],
#        [13.58955713],
#        [40.23430272],
#        [16.4358191 ],
#        [17.87260717]])

# %%
plt.scatter(y_test,pred)

# %%
residuals=y_test-pred

# %%
residuals
# Out:
#         Price
# 173 -5.377056
# 274 -4.715374
# 491 -1.616382
# 72  -2.884718
# 452 -2.422457
# ..        ...
# 441 -3.392184
# 23   0.910443
# 225  9.765697
# 433 -2.135819
# 447 -5.272607
#
# [152 rows x 1 columns]

# %%
sns.distplot(residuals,kde=True,hist=False)
# Out:
# C:\Users\bm101\AppData\Local\Temp\ipykernel_26228\3431768068.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals,kde=True,hist=False)
# C:\Users\bm101\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
# Performance Metrics

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 3.146968574368008
# 21.844584033084953
# 4.673818998750909

# %% [markdown]
# # pickling the Model for the Deployment

# %%
import pickle

pickle.dump(regression,open('reg_model.pkl','wb'))

# %%
pickled_model=pickle.load(open('reg_model.pkl','rb'))

# %%
X_train[0].reshape(1,-1)
# Out:
# array([[-0.42002854, -0.48778231, -1.31729854, -0.27565892, -0.85108479,
#          0.14526384, -0.37387593,  1.08162833, -0.74617905, -1.11279004,
#          0.18727079,  0.39651419, -1.04595325]])

# %%
pickled_model.predict(X_train[0].reshape(1,-1))
# Out:
# array([[25.34150238]])
